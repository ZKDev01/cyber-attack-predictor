# %%
import numpy as np 
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Cargar una muestra de access log file 
n_samples = 10
log_file_path = '../data/target/access_log_00.log'
with open(log_file_path, 'r') as f:
  sample_lines = [next(f).strip() for _ in range(n_samples)]
print("Sample log lines:")
for i,line in enumerate(sample_lines, 1):
  print(f"{i:>{len(str(n_samples))}}) {line}")

# %% [markdown]
# ### Carga e Comparación de CSIC Database CSV

# %%
# Load CSIC database CSV
csic_df = pd.read_csv('data/test_dataset/CSIC2010/csic_database.csv')
print("CSIC DataFrame shape:", csic_df.shape)
print("Columns:", csic_df.columns.tolist())
print("\nFirst 5 rows:")
print(csic_df.head())
print("\nData types:")
print(csic_df.dtypes)
print("\nBasic statistics:")
print(csic_df.describe(include='all'))
