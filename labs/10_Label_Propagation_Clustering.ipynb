# %% [markdown]
# # Importacion de Bibliotecas

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

import hdbscan

url_dataset = "../../Dataset/target/access_log_master_manual_labeling.csv"
url_dataset_modified= "../../Dataset/target/access_log_master_automatic_label.csv"

# %% [markdown]
# # Cargar dataset y definicion de variables

# %%
Day_to_analyze=["2025-11-19","2025-11-20","2025-11-21"]

df_original = pd.read_csv(url_dataset)
df_original["anomaly"] = df_original["anomaly"].replace({-1: np.nan})
df= df_original.copy()
mask = df["timestamp"].astype(str).str.startswith(tuple(Day_to_analyze))
df = df[mask]
df= df.head(10000)
anomaly_count= df["anomaly"].value_counts(dropna=False)
print(anomaly_count)
# Aseguramos NaN en no etiquetados

FEATURE_COLUMNS = [
    "status",
    "size",
    "status_category",

    "url__count_sql_words",
    "url__count_xss_words",
    "url__count_command_words",
    "url__count_auth_words",
    "url__count_error_words",
    "url__count_malware_words",
    "url__count_danger_characters",
    "url__count_obfuscation_code_words",
    "url__count_dir_words",
    "url__count_dot",
    "url__count_http",
    "url__count_percentage_symbol",
    "url__count_question_symbol",
    "url__count_hyphen",
    "url__count_equal",
    "url__url_length",
    "url__digit_count",
    "url__letter_count",
    "url__count_special_characters",
    "url__is_encoded",
    "url__unusual_character_ratio",
]
# Out:
# anomaly
# 0.0    5023
# NaN    4388
# 1.0     589
# Name: count, dtype: int64

# %% [markdown]
# # Preprocesamiento

# %% [markdown]
# # Clustering con HDBSCAN

# %%
def Craft_clusterer(t,df):
  X = df[FEATURE_COLUMNS]
  y = df["anomaly"]

  scaler = StandardScaler()
  X_scaled = scaler.fit_transform(X)
  
  clusterer = hdbscan.HDBSCAN(
    min_cluster_size=max(20, 40 - 5*t),
    min_samples=max(5, 15 - 2*t),
    metric="euclidean"
    )

  cluster_labels = clusterer.fit_predict(X_scaled)
  df["cluster"] = cluster_labels
  return df

# %% [markdown]
# # Funcion de Propagacion de etiquetas

# %%
def propagate_labels(df, label_col="anomaly", cluster_col="cluster", threshold=0.7):
    df = df.copy()
    new_labels = 0

    for cluster_id in df[cluster_col].unique():
        if cluster_id == -1:
            continue  # ruido

        cluster_data = df[df[cluster_col] == cluster_id]
        labeled = cluster_data[cluster_data[label_col].notna()]

        if len(labeled) == 0:
            continue

        label_counts = labeled[label_col].value_counts(normalize=True)
        dominant_label = label_counts.idxmax()
        confidence = label_counts.max()

        if confidence >= threshold:
            mask = (
                (df[cluster_col] == cluster_id) &
                (df[label_col].isna())
            )
            assigned = mask.sum()
            df.loc[mask, label_col] = dominant_label
            new_labels += assigned

    return df, new_labels

# %% [markdown]
# # Propagacion de etiquetas

# %%
MAX_ITERS = 10

def iterative_label_propagation(df, max_iters=MAX_ITERS, threshold=0.75):
    for i in range(max_iters):
        df = Craft_clusterer(i, df)
        df, assigned = propagate_labels(df, threshold=threshold)
        print(f"Iteración {i+1}: {assigned} nuevas etiquetas")
        if assigned == 0:
            break
    return df
df=iterative_label_propagation(df, max_iters=MAX_ITERS, threshold=0.75)
# Out:
# Iteración 1: 1451 nuevas etiquetas
# Iteración 2: 108 nuevas etiquetas
# Iteración 3: 52 nuevas etiquetas
# Iteración 4: 133 nuevas etiquetas
# Iteración 5: 30 nuevas etiquetas
# Iteración 6: 15 nuevas etiquetas
# Iteración 7: 0 nuevas etiquetas

# %%
value_counts = df["anomaly"].value_counts(dropna=False)
print(anomaly_count)
print(value_counts)
df.to_csv(url_dataset_modified, index=False)
# Out:
# anomaly
# 0.0    5023
# NaN    4388
# 1.0     589
# Name: count, dtype: int64
# anomaly
# 0.0    6383
# NaN    2599
# 1.0    1018
# Name: count, dtype: int64

# %% [markdown]
# # Probar la consistencia del Metodo

# %%
from sklearn.metrics import classification_report, f1_score
from sklearn.model_selection import train_test_split
def classification_report_propagation(df_original,i):
    # Solo datos con etiqueta original
    df_original_modfied= df_original[:10000]
    labeled_df = df_original_modfied[df_original_modfied["anomaly"].notna()].copy()
    # Ocultamos el 30%
    train_idx, test_idx = train_test_split(
        labeled_df.index,
        test_size=0.3,
        stratify=labeled_df["anomaly"],
        random_state=42+i
    )

    df_masked = df_original_modfied.copy()
    df_masked.loc[test_idx, "anomaly"] = np.nan

    df_masked=iterative_label_propagation(df_masked, max_iters=MAX_ITERS, threshold=0.75)
    y_true = df_original_modfied.loc[test_idx, "anomaly"].fillna(-1)
    y_pred = df_masked.loc[test_idx, "anomaly"].fillna(-1)
    return classification_report(y_true, y_pred,output_dict=True, zero_division=0)

# %% [markdown]
# # Comparar Resultados

# %%
def average_propagation_metrics(df_original, n_runs=10):
    reports = []

    for i in range(n_runs):
        report = classification_report_propagation(df_original,i)
        reports.append(report)

    # Convertimos a DataFrame
    df_reports = pd.json_normalize(reports)

    # Promedio
    mean_metrics = df_reports.mean()

    # Desviación estándar (opcional pero MUY recomendable)
    std_metrics = df_reports.std()

    return mean_metrics, std_metrics

mean_metrics, std_metrics = average_propagation_metrics(df_original)
# Out:
# Iteración 1: 3511 nuevas etiquetas
# Iteración 2: 149 nuevas etiquetas
# Iteración 3: 100 nuevas etiquetas
# Iteración 4: 71 nuevas etiquetas
# Iteración 5: 40 nuevas etiquetas
# Iteración 6: 34 nuevas etiquetas
# Iteración 7: 0 nuevas etiquetas
# Iteración 1: 3511 nuevas etiquetas
# Iteración 2: 149 nuevas etiquetas
# Iteración 3: 100 nuevas etiquetas
# Iteración 4: 71 nuevas etiquetas
# Iteración 5: 40 nuevas etiquetas
# Iteración 6: 34 nuevas etiquetas
# Iteración 7: 0 nuevas etiquetas
# Iteración 1: 3511 nuevas etiquetas
# Iteración 2: 149 nuevas etiquetas
# Iteración 3: 100 nuevas etiquetas
# Iteración 4: 71 nuevas etiquetas
# Iteración 5: 40 nuevas etiquetas
# Iteración 6: 34 nuevas etiquetas
# Iteración 7: 0 nuevas etiquetas
# Iteración 1: 3511 nuevas etiquetas
# Iteración 2: 149 nuevas etiquetas
# Iteración 3: 100 nuevas etiquetas
# Iteración 4: 71 nuevas etiquetas
# Iteración 5: 40 nuevas etiquetas
# Iteración 6: 34 nuevas etiquetas
# Iteración 7: 0 nuevas etiquetas
# Iteración 1: 3511 nuevas etiquetas
# Iteración 2: 149 nuevas etiquetas
# Iteración 3: 100 nuevas etiquetas
# Iteración 4: 71 nuevas etiquetas
# Iteración 5: 40 nuevas etiquetas
# Iteración 6: 34 nuevas etiquetas
# Iteración 7: 0 nuevas etiquetas
# Iteración 1: 3511 nuevas etiquetas
# Iteración 2: 149 nuevas etiquetas
# Iteración 3: 100 nuevas etiquetas
# Iteración 4: 71 nuevas etiquetas
# Iteración 5: 40 nuevas etiquetas
# Iteración 6: 34 nuevas etiquetas
# Iteración 7: 0 nuevas etiquetas
# Iteración 1: 3511 nuevas etiquetas
# Iteración 2: 149 nuevas etiquetas
# Iteración 3: 100 nuevas etiquetas
# Iteración 4: 71 nuevas etiquetas
# Iteración 5: 40 nuevas etiquetas
# Iteración 6: 34 nuevas etiquetas
# Iteración 7: 0 nuevas etiquetas
# Iteración 1: 3511 nuevas etiquetas
# Iteración 2: 149 nuevas etiquetas
# Iteración 3: 100 nuevas etiquetas
# Iteración 4: 71 nuevas etiquetas
# Iteración 5: 40 nuevas etiquetas
# Iteración 6: 34 nuevas etiquetas
# Iteración 7: 0 nuevas etiquetas
# Iteración 1: 3511 nuevas etiquetas
# Iteración 2: 149 nuevas etiquetas
# Iteración 3: 100 nuevas etiquetas
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 19
#      15     std_metrics = df_reports.std()
#      17     return mean_metrics, std_metrics
# ---> 19 mean_metrics, std_metrics = average_propagation_metrics(df_original)
#
# Cell In[11], line 5, in average_propagation_metrics(df_original, n_runs)
#       2 reports = []
#       4 for i in range(n_runs):
# ----> 5     report = classification_report_propagation(df_original,0)
#       6     reports.append(report)
#       8 # Convertimos a DataFrame
#
# Cell In[8], line 18, in classification_report_propagation(df_original, i)
#      15 df_masked = df_original_modfied.copy()
#      16 df_masked.loc[test_idx, "anomaly"] = np.nan
# ---> 18 df_masked=iterative_label_propagation(df_masked, max_iters=MAX_ITERS, threshold=0.75)
#      19 y_true = df_original_modfied.loc[test_idx, "anomaly"].fillna(-1)
#      20 y_pred = df_masked.loc[test_idx, "anomaly"].fillna(-1)
#
# Cell In[7], line 5, in iterative_label_propagation(df, max_iters, threshold)
#       3 def iterative_label_propagation(df, max_iters=MAX_ITERS, threshold=0.75):
#       4     for i in range(max_iters):
# ----> 5         df = Craft_clusterer(i, df)
#       6         df, assigned = propagate_labels(df, threshold=threshold)
#       7         print(f"Iteración {i+1}: {assigned} nuevas etiquetas")
#
# Cell In[5], line 14, in Craft_clusterer(t, df)
#       6 X_scaled = scaler.fit_transform(X)
#       8 clusterer = hdbscan.HDBSCAN(
#       9   min_cluster_size=max(20, 40 - 5*t),
#      10   min_samples=max(5, 15 - 2*t),
#      11   metric="euclidean"
#      12   )
# ---> 14 cluster_labels = clusterer.fit_predict(X_scaled)
#      15 df["cluster"] = cluster_labels
#      16 return df
#
# File /run/media/jotogo/01DC27E75878C270/Universidad/4to Año/ML/Proyecto/cyber-attack-predictor/.venv/lib/python3.13/site-packages/hdbscan/hdbscan_.py:1312, in HDBSCAN.fit_predict(self, X, y)
#    1297 def fit_predict(self, X, y=None):
#    1298     """Performs clustering on X and returns cluster labels.
#    1299
#    1300     Parameters
#    (...)   1310         cluster labels
#    1311     """
# -> 1312     self.fit(X)
#    1313     return self.labels_
#
# File /run/media/jotogo/01DC27E75878C270/Universidad/4to Año/ML/Proyecto/cyber-attack-predictor/.venv/lib/python3.13/site-packages/hdbscan/hdbscan_.py:1272, in HDBSCAN.fit(self, X, y)
#    1262 kwargs.update(self._metric_kwargs)
#    1263 kwargs['gen_min_span_tree'] |= self.branch_detection_data
#    1265 (
#    1266     self.labels_,
#    1267     self.probabilities_,
#    1268     self.cluster_persistence_,
#    1269     self._condensed_tree,
#    1270     self._single_linkage_tree,
#    1271     self._min_spanning_tree,
# -> 1272 ) = hdbscan(clean_data, **kwargs)
#    1274 if self.metric != "precomputed" and not self._all_finite:
#    1275     # remap indices to align with original data in the case of non-finite entries.
#    1276     self._condensed_tree = remap_condensed_tree(
#    1277         self._condensed_tree, internal_to_raw, outliers
#    1278     )
#
# File /run/media/jotogo/01DC27E75878C270/Universidad/4to Año/ML/Proyecto/cyber-attack-predictor/.venv/lib/python3.13/site-packages/hdbscan/hdbscan_.py:868, in hdbscan(X, min_cluster_size, min_samples, alpha, cluster_selection_epsilon, cluster_selection_persistence, max_cluster_size, metric, p, leaf_size, algorithm, memory, approx_min_span_tree, gen_min_span_tree, core_dist_n_jobs, cluster_selection_method, allow_single_cluster, match_reference_implementation, cluster_selection_epsilon_max, **kwargs)
#     855         (single_linkage_tree, result_min_span_tree) = memory.cache(
#     856             _hdbscan_prims_kdtree
#     857         )(
#    (...)    865             **kwargs
#     866         )
#     867     else:
# --> 868         (single_linkage_tree, result_min_span_tree) = memory.cache(
#     869             _hdbscan_boruvka_kdtree
#     870         )(
#     871             X,
#     872             min_samples,
#     873             alpha,
#     874             metric,
#     875             p,
#     876             leaf_size,
#     877             approx_min_span_tree,
#     878             gen_min_span_tree,
#     879             core_dist_n_jobs,
#     880             **kwargs
#     881         )
#     882 else:  # Metric is a valid BallTree metric
#     883     # TO DO: Need heuristic to decide when to go to boruvka;
#     884     # still debugging for now
#     885     if X.shape[1] > 60:
#
# File /run/media/jotogo/01DC27E75878C270/Universidad/4to Año/ML/Proyecto/cyber-attack-predictor/.venv/lib/python3.13/site-packages/joblib/memory.py:326, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     325 def __call__(self, *args, **kwargs):
# --> 326     return self.func(*args, **kwargs)
#
# File /run/media/jotogo/01DC27E75878C270/Universidad/4to Año/ML/Proyecto/cyber-attack-predictor/.venv/lib/python3.13/site-packages/hdbscan/hdbscan_.py:355, in _hdbscan_boruvka_kdtree(X, min_samples, alpha, metric, p, leaf_size, approx_min_span_tree, gen_min_span_tree, core_dist_n_jobs, **kwargs)
#     345 tree = KDTree(X, metric=metric, leaf_size=leaf_size, **kwargs)
#     346 alg = KDTreeBoruvkaAlgorithm(
#     347     tree,
#     348     min_samples,
#    (...)    353     **kwargs
#     354 )
# --> 355 min_spanning_tree = alg.spanning_tree()
#     356 # Sort edges of the min_spanning_tree by weight
#     357 row_order = np.argsort(min_spanning_tree.T[2])
#
# KeyboardInterrupt:

# %%
print("Métricas promedio después de la propagación de etiquetas:")
for metric, value in mean_metrics.items():
    print(f"{metric}: {value:.4f} ± {std_metrics[metric]:.4f}")
# Out:
# Métricas promedio después de la propagación de etiquetas:
# accuracy: 0.8811 ± nan
# -1.0.precision: 0.0000 ± nan
# -1.0.recall: 0.0000 ± nan
# -1.0.f1-score: 0.0000 ± nan
# -1.0.support: 0.0000 ± nan
# 0.0.precision: 0.9943 ± nan
# 0.0.recall: 0.8922 ± nan
# 0.0.f1-score: 0.9405 ± nan
# 0.0.support: 1169.0000 ± nan
# 1.0.precision: 0.8824 ± nan
# 1.0.recall: 0.7947 ± nan
# 1.0.f1-score: 0.8362 ± nan
# 1.0.support: 151.0000 ± nan
# macro avg.precision: 0.6255 ± nan
# macro avg.recall: 0.5623 ± nan
# macro avg.f1-score: 0.5922 ± nan
# macro avg.support: 1320.0000 ± nan
# weighted avg.precision: 0.9815 ± nan
# weighted avg.recall: 0.8811 ± nan
# weighted avg.f1-score: 0.9286 ± nan
# weighted avg.support: 1320.0000 ± nan
